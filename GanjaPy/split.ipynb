# %%
import ganja.io as io
import ganja.preprocessing as preprocessing
import ganja.utils as utils
# Out:
# Welcome to JupyROOT 6.10/02

# %%
from glob import glob
import os

reload(io)
reload(preprocessing)

# import ROOT as RT

from glob import glob

class Parameters(utils.Parameters):
    base = utils.param(os.getenv('SCRATCH')+'/ganja')
    version = utils.param('nov2')
    postfix = utils.param('_v3')
    nparts = utils.param(200)
    njobs = utils.param(10)
    compress = utils.param(False)
    
class MyApp(utils.MyApp):
    classes = utils.List([Parameters])

# Read all parameters above from command line. 
# Note: names are all converted to be all capital
notebook_parameters = Parameters(MyApp()).get_params()

# copy parameters to global scope
globals().update(notebook_parameters)

notebook_parameters
# Out:
# {'BASE': '/scratch/snx3000/musella/ganja',
#  'COMPRESS': False,
#  'NJOBS': 10,
#  'NPARTS': 200,
#  'POSTFIX': '_v3',
#  'VERSION': 'nov2'}

# %%
folders = glob(BASE+'/converted/'+VERSION+'/QCD*')

inputs = {}
for folder in folders:
    files = list(map(lambda x: int(os.path.basename(x).replace('.json','')), glob('%s/*.json' % folder) ))
    # files = list(map(lambda x: int(os.path.basename(x).replace('.json','')), glob('%s/[0-9].json' % folder) ))
    # files = list(map(lambda x: int(os.path.basename(x).replace('.json','')), glob('%s/*.json' % folder)[:10] ))
    inputs[folder] = files

# %%
reload(io)
proc_ids,df = io.read_datasets(inputs,randomize_file=np.arange(0,10))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', description='reading datasets', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=138), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=159), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=148), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=191), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=150), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=66), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=91), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=194), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=38), HTML(value='')))

# %%
reload(io)             

io.make_partitions(df,NPARTS/10,proc_ids,BASE+'/split/'+VERSION+POSTFIX,n_jobs=NJOBS,compress=COMPRESS)
# Out:
# Partitioning images
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', description='QCD_Pt_1800', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=17), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=26), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=11), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=13), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=7), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=14), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=20), HTML(value='')))
# ...
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=6), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_30to50', max=21), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_80to120', max=23), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_600to800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_120to170', max=20), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_470to600', max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_800to1000', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_300to470', max=22), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_50to80', max=18), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1000to1400', max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1400to1800', max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_170to300', max=25), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='QCD_Pt_1800', max=4), HTML(value='')))
# Partitioning infos
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))

# %%
np.random.choice(np.arange(200 % 5))

# %%
np.arange(1,11)
